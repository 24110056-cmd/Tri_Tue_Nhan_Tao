# %%
import heapq
START_STATE = (1, 2, 3, 4, 0, 6, 7, 5, 8)
GOAL_STATE  = (1, 2, 3, 4, 5, 6, 7, 8, 0)
def get_ucs_successors(state):
    successors = []
    blank_idx = state.index(0)
    row, col = blank_idx // 3, blank_idx % 3
    for move, diff in [('U', -3), ('D', 3), ('L', -1), ('R', 1)]:
        if move == 'U' and row == 0: continue
        if move == 'D' and row == 2: continue
        if move == 'L' and col == 0: continue
        if move == 'R' and col == 2: continue
        new_idx = blank_idx + diff
        new_state = list(state)
        cost = new_state[new_idx] 
        new_state[blank_idx], new_state[new_idx] = new_state[new_idx], new_state[blank_idx]
        successors.append((tuple(new_state), cost))
    return successors
def state_to_str(state):
    if state == START_STATE: return "S"
    if state == GOAL_STATE: return "GOAL"
    return f"N_{state.index(0)}"
def print_matrix(state):
    print(f"[{state[0]} {state[1]} {state[2]}]")
    print(f"[{state[3]} {state[4]} {state[5]}]")
    print(f"[{state[6]} {state[7]} {state[8]}]\n")
def print_row_ucs(action, frontier, reached, note=""):
    f_str = "[" + ", ".join([f"{state_to_str(x[1])}({x[0]})" for x in sorted(frontier)]) + "]"
    r_str = "{" + ", ".join([f"{state_to_str(k)}:{v}" for k, v in reached.items()]) + "}"
    print(f"{action:<18} | {f_str:<32} | {r_str:<30} | {note}")
def uniform_cost_search_trace(start):
    reached = {start: 0}
    frontier = []
    heapq.heappush(frontier, (0, start, [start]))
    print("-" * 110)
    print(f"{'Hành động (Node)':<18} | {'F (Frontier - Priority Queue)':<32} | {'R (Reached)':<30} | Ghi chú")
    print("-" * 110)
    print_row_ucs("(Khởi tạo)", frontier, reached, "Khởi tạo nút gốc S với g=0")
    while frontier:
        g_cost, current_node, path = heapq.heappop(frontier)
        node_name = state_to_str(current_node)
        print_row_ucs(f"POP {node_name}({g_cost})", frontier, reached, f"Lấy nút rẻ nhất trong F")
        if current_node == GOAL_STATE:
            print_row_ucs(f"Check {node_name}", frontier, reached, "-> TRÙNG GOAL! THÀNH CÔNG.")
            return path, g_cost
        print_row_ucs(f"Check {node_name}", frontier, reached, f"-> {node_name} != GOAL")
        has_child = False
        for child, edge_cost in get_ucs_successors(current_node):
            new_g = g_cost + edge_cost
            if child not in reached or new_g < reached[child]:
                reached[child] = new_g
                heapq.heappush(frontier, (new_g, child, path + [child]))
                has_child = True
        if has_child:
            print_row_ucs("(Nạp con vào F)", frontier, reached, f"Cập nhật g và nạp các con của {node_name}")
        print("-" * 110)
    return None, float('inf')
print("=== BẢNG TRACE CHI TIẾT THUẬT TOÁN UCS ===")
ucs_path, total_cost = uniform_cost_search_trace(START_STATE)
print("\n" + "="*50)
print(f"TỔNG CHI PHÍ TỐI ƯU TÌM ĐƯỢC: {total_cost}")
print("="*50 + "\n")
print("CHI TIẾT CÁC BƯỚC DỊCH CHUYỂN TỐI ƯU:")
for idx, st in enumerate(ucs_path):
    print(f"Bước {idx}:")
    print_matrix(st)
# Out:
# === BẢNG TRACE CHI TIẾT THUẬT TOÁN UCS ===
# --------------------------------------------------------------------------------------------------------------
# Hành động (Node)   | F (Frontier - Priority Queue)    | R (Reached)                    | Ghi chú
# --------------------------------------------------------------------------------------------------------------
# (Khởi tạo)         | [S(0)]                           | {S:0}                          | Khởi tạo nút gốc S với g=0
# POP S(0)           | []                               | {S:0}                          | Lấy nút rẻ nhất trong F
# Check S            | []                               | {S:0}                          | -> S != GOAL
# (Nạp con vào F)    | [N_1(2), N_3(4), N_7(5), N_5(6)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6} | Cập nhật g và nạp các con của S
# --------------------------------------------------------------------------------------------------------------
# POP N_1(2)         | [N_3(4), N_7(5), N_5(6)]         | {S:0, N_1:2, N_7:5, N_3:4, N_5:6} | Lấy nút rẻ nhất trong F
# Check N_1          | [N_3(4), N_7(5), N_5(6)]         | {S:0, N_1:2, N_7:5, N_3:4, N_5:6} | -> N_1 != GOAL
# (Nạp con vào F)    | [N_0(3), N_3(4), N_7(5), N_2(5), N_5(6)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5} | Cập nhật g và nạp các con của N_1
# --------------------------------------------------------------------------------------------------------------
# POP N_0(3)         | [N_3(4), N_7(5), N_2(5), N_5(6)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5} | Lấy nút rẻ nhất trong F
# Check N_0          | [N_3(4), N_7(5), N_2(5), N_5(6)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5} | -> N_0 != GOAL
# (Nạp con vào F)    | [N_3(4), N_7(5), N_2(5), N_5(6), N_3(7)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7} | Cập nhật g và nạp các con của N_0
# --------------------------------------------------------------------------------------------------------------
# POP N_3(4)         | [N_7(5), N_2(5), N_5(6), N_3(7)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7} | Lấy nút rẻ nhất trong F
# Check N_3          | [N_7(5), N_2(5), N_5(6), N_3(7)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7} | -> N_3 != GOAL
# (Nạp con vào F)    | [N_0(5), N_7(5), N_2(5), N_5(6), N_3(7), N_6(11)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11} | Cập nhật g và nạp các con của N_3
# --------------------------------------------------------------------------------------------------------------
# POP N_0(5)         | [N_7(5), N_2(5), N_5(6), N_3(7), N_6(11)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11} | Lấy nút rẻ nhất trong F
# Check N_0          | [N_7(5), N_2(5), N_5(6), N_3(7), N_6(11)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11} | -> N_0 != GOAL
# (Nạp con vào F)    | [N_7(5), N_2(5), N_5(6), N_1(7), N_3(7), N_6(11)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7} | Cập nhật g và nạp các con của N_0
# --------------------------------------------------------------------------------------------------------------
# POP N_7(5)         | [N_2(5), N_5(6), N_1(7), N_3(7), N_6(11)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7} | Lấy nút rẻ nhất trong F
# Check N_7          | [N_2(5), N_5(6), N_1(7), N_3(7), N_6(11)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7} | -> N_7 != GOAL
# (Nạp con vào F)    | [N_2(5), N_5(6), N_1(7), N_3(7), N_6(11), N_6(12), GOAL(13)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13} | Cập nhật g và nạp các con của N_7
# --------------------------------------------------------------------------------------------------------------
# POP N_2(5)         | [N_5(6), N_1(7), N_3(7), N_6(11), N_6(12), GOAL(13)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13} | Lấy nút rẻ nhất trong F
# Check N_2          | [N_5(6), N_1(7), N_3(7), N_6(11), N_6(12), GOAL(13)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13} | -> N_2 != GOAL
# (Nạp con vào F)    | [N_5(6), N_1(7), N_3(7), N_6(11), N_5(11), N_6(12), GOAL(13)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11} | Cập nhật g và nạp các con của N_2
# --------------------------------------------------------------------------------------------------------------
# POP N_5(6)         | [N_1(7), N_3(7), N_6(11), N_5(11), N_6(12), GOAL(13)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11} | Lấy nút rẻ nhất trong F
# Check N_5          | [N_1(7), N_3(7), N_6(11), N_5(11), N_6(12), GOAL(13)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11} | -> N_5 != GOAL
# (Nạp con vào F)    | [N_1(7), N_3(7), N_2(9), N_6(11), N_5(11), N_6(12), GOAL(13), N_8(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14} | Cập nhật g và nạp các con của N_5
# --------------------------------------------------------------------------------------------------------------
# POP N_1(7)         | [N_3(7), N_2(9), N_6(11), N_5(11), N_6(12), GOAL(13), N_8(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14} | Lấy nút rẻ nhất trong F
# Check N_1          | [N_3(7), N_2(9), N_6(11), N_5(11), N_6(12), GOAL(13), N_8(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14} | -> N_1 != GOAL
# (Nạp con vào F)    | [N_3(7), N_2(9), N_2(10), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10} | Cập nhật g và nạp các con của N_1
# --------------------------------------------------------------------------------------------------------------
# POP N_3(7)         | [N_2(9), N_2(10), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10} | Lấy nút rẻ nhất trong F
# Check N_3          | [N_2(9), N_2(10), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10} | -> N_3 != GOAL
# (Nạp con vào F)    | [N_2(9), N_4(9), N_2(10), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_6(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9} | Cập nhật g và nạp các con của N_3
# --------------------------------------------------------------------------------------------------------------
# POP N_2(9)         | [N_4(9), N_2(10), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_6(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9} | Lấy nút rẻ nhất trong F
# Check N_2          | [N_4(9), N_2(10), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_6(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9} | -> N_2 != GOAL
# (Nạp con vào F)    | [N_4(9), N_2(10), N_1(11), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_6(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11} | Cập nhật g và nạp các con của N_2
# --------------------------------------------------------------------------------------------------------------
# POP N_4(9)         | [N_2(10), N_1(11), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_6(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11} | Lấy nút rẻ nhất trong F
# Check N_4          | [N_2(10), N_1(11), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_6(14)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11} | -> N_4 != GOAL
# (Nạp con vào F)    | [N_2(10), N_1(10), N_1(11), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_7(14), N_6(14), N_5(15)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15} | Cập nhật g và nạp các con của N_4
# --------------------------------------------------------------------------------------------------------------
# POP N_2(10)        | [N_1(10), N_1(11), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_7(14), N_6(14), N_5(15)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15} | Lấy nút rẻ nhất trong F
# Check N_2          | [N_1(10), N_1(11), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_7(14), N_6(14), N_5(15)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15} | -> N_2 != GOAL
# (Nạp con vào F)    | [N_1(10), N_1(11), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_7(14), N_6(14), N_5(15), N_5(16)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16} | Cập nhật g và nạp các con của N_2
# --------------------------------------------------------------------------------------------------------------
# POP N_1(10)        | [N_1(11), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_7(14), N_6(14), N_5(15), N_5(16)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16} | Lấy nút rẻ nhất trong F
# Check N_1          | [N_1(11), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_8(14), N_7(14), N_6(14), N_5(15), N_5(16)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16} | -> N_1 != GOAL
# (Nạp con vào F)    | [N_1(11), N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_5(16)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13} | Cập nhật g và nạp các con của N_1
# --------------------------------------------------------------------------------------------------------------
# POP N_1(11)        | [N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_5(16)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13} | Lấy nút rẻ nhất trong F
# Check N_1          | [N_6(11), N_5(11), N_4(11), N_6(12), GOAL(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_5(16)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13} | -> N_1 != GOAL
# (Nạp con vào F)    | [N_6(11), N_5(11), N_4(11), N_0(12), N_6(12), GOAL(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_5(16), N_4(17)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12} | Cập nhật g và nạp các con của N_1
# --------------------------------------------------------------------------------------------------------------
# POP N_6(11)        | [N_5(11), N_4(11), N_0(12), N_6(12), GOAL(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_5(16), N_4(17)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12} | Lấy nút rẻ nhất trong F
# Check N_6          | [N_5(11), N_4(11), N_0(12), N_6(12), GOAL(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_5(16), N_4(17)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12} | -> N_6 != GOAL
# (Nạp con vào F)    | [N_5(11), N_4(11), N_0(12), N_6(12), GOAL(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_4(17)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16} | Cập nhật g và nạp các con của N_6
# --------------------------------------------------------------------------------------------------------------
# POP N_5(11)        | [N_4(11), N_0(12), N_6(12), GOAL(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_4(17)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16} | Lấy nút rẻ nhất trong F
# Check N_5          | [N_4(11), N_0(12), N_6(12), GOAL(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_4(17)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16} | -> N_5 != GOAL
# (Nạp con vào F)    | [N_4(11), N_0(12), N_6(12), GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_4(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13} | Cập nhật g và nạp các con của N_5
# --------------------------------------------------------------------------------------------------------------
# POP N_4(11)        | [N_0(12), N_6(12), GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_4(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13} | Lấy nút rẻ nhất trong F
# Check N_4          | [N_0(12), N_6(12), GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_4(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13} | -> N_4 != GOAL
# (Nạp con vào F)    | [N_0(12), N_6(12), N_3(12), GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_7(16), N_4(17), N_5(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17} | Cập nhật g và nạp các con của N_4
# --------------------------------------------------------------------------------------------------------------
# POP N_0(12)        | [N_6(12), N_3(12), GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_7(16), N_4(17), N_5(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17} | Lấy nút rẻ nhất trong F
# Check N_0          | [N_6(12), N_3(12), GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_7(16), N_4(17), N_5(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17} | -> N_0 != GOAL
# (Nạp con vào F)    | [N_6(12), N_3(12), GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_7(16), N_3(16), N_4(17), N_5(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17, N_3:16} | Cập nhật g và nạp các con của N_0
# --------------------------------------------------------------------------------------------------------------
# POP N_6(12)        | [N_3(12), GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_7(16), N_3(16), N_4(17), N_5(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17, N_3:16} | Lấy nút rẻ nhất trong F
# Check N_6          | [N_3(12), GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_7(16), N_5(16), N_7(16), N_3(16), N_4(17), N_5(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17, N_3:16} | -> N_6 != GOAL
# (Nạp con vào F)    | [N_3(12), GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_3(16), N_7(16), N_5(16), N_7(16), N_3(16), N_4(17), N_5(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17, N_3:16, N_3:16} | Cập nhật g và nạp các con của N_6
# --------------------------------------------------------------------------------------------------------------
# POP N_3(12)        | [GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_3(16), N_7(16), N_5(16), N_7(16), N_3(16), N_4(17), N_5(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17, N_3:16, N_3:16} | Lấy nút rẻ nhất trong F
# Check N_3          | [GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_3(16), N_7(16), N_5(16), N_7(16), N_3(16), N_4(17), N_5(17), N_8(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17, N_3:16, N_3:16} | -> N_3 != GOAL
# (Nạp con vào F)    | [GOAL(13), N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_3(16), N_7(16), N_5(16), N_7(16), N_3(16), N_4(17), N_5(17), N_8(19), N_6(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17, N_3:16, N_3:16, N_6:19} | Cập nhật g và nạp các con của N_3
# --------------------------------------------------------------------------------------------------------------
# POP GOAL(13)       | [N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_3(16), N_7(16), N_5(16), N_7(16), N_3(16), N_4(17), N_5(17), N_8(19), N_6(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17, N_3:16, N_3:16, N_6:19} | Lấy nút rẻ nhất trong F
# Check GOAL         | [N_4(13), N_2(13), N_0(14), N_8(14), N_7(14), N_6(14), N_5(15), N_3(16), N_7(16), N_5(16), N_7(16), N_3(16), N_4(17), N_5(17), N_8(19), N_6(19)] | {S:0, N_1:2, N_7:5, N_3:4, N_5:6, N_0:3, N_2:5, N_3:7, N_0:5, N_6:11, N_1:7, N_6:12, GOAL:13, N_5:11, N_2:9, N_8:14, N_4:11, N_2:10, N_6:14, N_4:9, N_1:11, N_1:10, N_7:14, N_5:15, N_5:16, N_0:14, N_2:13, N_4:17, N_0:12, N_7:16, N_8:19, N_4:13, N_7:16, N_3:12, N_5:17, N_3:16, N_3:16, N_6:19} | -> TRÙNG GOAL! THÀNH CÔNG.
#
# ==================================================
# TỔNG CHI PHÍ TỐI ƯU TÌM ĐƯỢC: 13
# ==================================================
#
# CHI TIẾT CÁC BƯỚC DỊCH CHUYỂN TỐI ƯU:
# Bước 0:
# [1 2 3]
# [4 0 6]
# [7 5 8]
#
# Bước 1:
# [1 2 3]
# [4 5 6]
# [7 0 8]
#
# Bước 2:
# [1 2 3]
# [4 5 6]
# [7 8 0]
